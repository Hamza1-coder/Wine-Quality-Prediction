# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# #### FEATURES DESCRIPTION
#
# |**Fixed acidity**: It indicates the amount of tartaric acid in wine and is measured in g/dm3
#
# |**Volatile acidity**: It indicates the amount of acetic acid in the wine. It is measured in g/dm3.
#
# |**Citric acid**: It indicates the amount of citric acid in the wine. It is also measured in g/dm3
#
# |**Residual sugar**: It indicates the amount of sugar left in the wine after the fermentation process is done. It is also measured in g/dm3
#
# |**Free sulfur dioxide**: It measures the amount of sulfur dioxide (SO2) in free form. It is also measured in g/dm3
#
# |**Total sulfur dioxide**: It measures the total amount of SO2 in the wine. This chemical works as an antioxidant and antimicrobial agent.
#
# |**Density**: It indicates the density of the wine and is measured in g/dm3.
#
# |**pH**: It indicates the pH value of the wine. The range of value is between 0 to 14.0, which indicates very high acidity, and 14 indicates basic acidity.
#
# |**Sulphates**: It indicates the amount of potassium sulphate in the wine. It is also measured in g/dm3.
#
# |**Alcohol**: It indicates the alcohol content in the wine.
#
# |**Quality**: It indicates the quality of the wine, which is ranged from 3 to 8. Here, the higher the value is, the better the wine.

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# ### Observation:
# In **quality column** maximum value is 8 which denotes to best quality of wine.
#
# In **quality column** minimum value is 3 which denotes to worst quality of wine.
#
# In **quality column** the average quality of wine is near about 5.63.

# %%
best_quality_wine = df[df['quality'] == 8]
best_quality_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count      18.000000         18.000000    18.000000       18.000000
# mean        8.566667          0.423333     0.391111        2.577778
# std         2.119656          0.144914     0.199526        1.295038
# min         5.000000          0.260000     0.030000        1.400000
# 25%         7.250000          0.335000     0.302500        1.800000
# 50%         8.250000          0.370000     0.420000        2.100000
# 75%        10.225000          0.472500     0.530000        2.600000
# max        12.600000          0.850000     0.720000        6.400000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count  18.000000            18.000000             18.000000  18.000000
# mean    0.068444            13.277778             33.444444   0.995212
# std     0.011678            11.155613             25.433240   0.002378
# ...

# %%
worst_quality_wine = df[df['quality'] == 3]
worst_quality_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count      10.000000         10.000000    10.000000       10.000000
# mean        8.360000          0.884500     0.171000        2.635000
# std         1.770875          0.331256     0.250664        1.401596
# min         6.700000          0.440000     0.000000        1.200000
# 25%         7.150000          0.647500     0.005000        1.875000
# 50%         7.500000          0.845000     0.035000        2.100000
# 75%         9.875000          1.010000     0.327500        3.100000
# max        11.600000          1.580000     0.660000        5.700000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count  10.000000            10.000000             10.000000  10.000000
# mean    0.122500            11.000000             24.900000   0.997464
# std     0.066241             9.763879             16.828877   0.002002
# ...

# %%
difference_between_best_and_worst = []
best = [8.566667,0.423333,0.391111,2.577778,0.068444,13.277778,33.444444,0.995212,3.267222,0.767778,12.094444,8.0]
worst = [8.360000,0.884500,0.171000,2.635000,0.122500,11.000000,24.900000,0.997464,3.398000,0.57000,9.955000,3.0]
for i in range(12):
    difference = best[i] - worst[i]
    difference_between_best_and_worst.append(difference)
difference_between_best_and_worst
# Out:
# [0.20666700000000127,
#  -0.46116699999999994,
#  0.22011099999999997,
#  -0.057221999999999884,
#  -0.05405599999999999,
#  2.2777779999999996,
#  8.544443999999999,
#  -0.0022520000000000318,
#  -0.13077800000000028,
#  0.197778,
#  2.1394439999999992,
#  5.0]

# %% [markdown]
# ### Observation:
# * The quantity of **free sulfur dioxide** is higher in best wine as compare to worst wine. (difference of 2.27)
# * The quantity of **total sulfur dioxide** is higher in best wine as compare to worst wine. (difference of 8.5)
# * The quantity of **alcohol** is higher in best wine as compare to worst wine. (difference of 2.13)
# ### Conclusion:
# * **total sulfur dioxide** has a major impact on the quality of wine and vice verca.

# %% [markdown]
# # Visualize Analysis

# %%
sns.set(rc={'figure.figsize':(14, 8)})
sns.countplot(df['quality'])
# Out:
# /home/robot/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
def box_strip_plot(target, lst):
    for i in lst:
        f, axes = plt.subplots(1,2,figsize=(14,4))
        sns.boxplot(x=df[target], y = df[i], width =0.5, ax=axes[0]).set_title("Boxplot of "+i)
        axes[0].yaxis.tick_left()
        
        sns.stripplot(x=df[target], y = df[i], dodge=True, ax=axes[1]).set_title("Stripplot of "+i)
        axes[1].yaxis.set_label_position("right")
        axes[1].yaxis.tick_right()
        plt.show()

# %%
columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']
box_strip_plot('quality', columns)

# %%
def bar_plot(target,lst):
    for i in lst:
        plot = plt.figure(figsize=(5,5))
        sns.barplot(x=df[target], y=df[i], data=df)
        plt.title("Quality Vs "+i)
        plt.show()

# %%
bar_plot('quality',columns)

# %% [markdown]
# ## Correaltion
# * Positive
# * Negative

# %%
cor = df.corr()
plt.figure(figsize=(9,9))
sns.heatmap(cor, cbar=True, square=True, fmt='.1f', 
            annot=True, annot_kws={'size':8}, cmap='Blues')
plt.show()

# %% [markdown]
# ### Observation:
# * alcohole is more coorealated to quality (0.5)

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
X = df.drop(columns=['quality'], axis=1)
y = df['quality'].apply(lambda x: 1 if x>=7 else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=2)

# %% [markdown]
# # Train Model Using RandomForestClassifier

# %%
rfr = RandomForestClassifier()

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
## Accuraacy Score
x_pred = rfr.predict(X_test)
test_accuracy = accuracy_score(x_pred, y_test)
print('Accuracy: ', test_accuracy)
# Out:
# Accuracy:  0.921875

# %% [markdown]
# # Bulilding a Predictive System

# %%
def prediction(lst):
    lst = np.array(lst)
    _list = lst.reshape(1,-1)
    predict = rfr.predict(_list)
    if predict[0] == 1:
        print("Good Quality of Wine")
    else:
        print("Bad Quality of Wine")

# %% [markdown]
# ## Testing System for both cases

# %%
prediction(df.iloc[0:1,0:-1])
# Out:
# Bad Quality of Wine

# %%
prediction(df.iloc[205:206,0:-1])
# Out:
# Good Quality of Wine
